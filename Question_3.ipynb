# %% [markdown]
# Mfundo Monchwe
# 201726904
# Question 3

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
n =5
X = np.linspace(-5,5,n)

# %% [markdown]
# 3,1

# %%
cov_f1 = lambda x_n: np.array([np.exp(-(x_n - x_m)**2/2) for x_m in x_n])

# %%
cov_f1(X)
# Out:
# array([[1.00000000e+00, 4.39369336e-02, 3.72665317e-06, 6.10193668e-13,
#         1.92874985e-22],
#        [4.39369336e-02, 1.00000000e+00, 4.39369336e-02, 3.72665317e-06,
#         6.10193668e-13],
#        [3.72665317e-06, 4.39369336e-02, 1.00000000e+00, 4.39369336e-02,
#         3.72665317e-06],
#        [6.10193668e-13, 3.72665317e-06, 4.39369336e-02, 1.00000000e+00,
#         4.39369336e-02],
#        [1.92874985e-22, 6.10193668e-13, 3.72665317e-06, 4.39369336e-02,
#         1.00000000e+00]])

# %% [markdown]
# 3.2

# %%
cov_f2 = lambda x_n: np.array([(10 + x_n.T.dot(x_m))**2for x_m in x_n])

# %%
cov_f2(X)
# Out:
# array([[1225.    ,  506.25  ,  100.    ,    6.25  ,  225.    ],
#        [ 506.25  ,  264.0625,  100.    ,   14.0625,    6.25  ],
#        [ 100.    ,  100.    ,  100.    ,  100.    ,  100.    ],
#        [   6.25  ,   14.0625,  100.    ,  264.0625,  506.25  ],
#        [ 225.    ,    6.25  ,  100.    ,  506.25  , 1225.    ]])

# %% [markdown]
# 3.3

# %%
cov_f3 = lambda x_n: np.array([np.exp(-(x_n - x_m)) for x_m in x_n])

# %%
cov_f3(X)
# Out:
# array([[1.00000000e+00, 8.20849986e-02, 6.73794700e-03, 5.53084370e-04,
#         4.53999298e-05],
#        [1.21824940e+01, 1.00000000e+00, 8.20849986e-02, 6.73794700e-03,
#         5.53084370e-04],
#        [1.48413159e+02, 1.21824940e+01, 1.00000000e+00, 8.20849986e-02,
#         6.73794700e-03],
#        [1.80804241e+03, 1.48413159e+02, 1.21824940e+01, 1.00000000e+00,
#         8.20849986e-02],
#        [2.20264658e+04, 1.80804241e+03, 1.48413159e+02, 1.21824940e+01,
#         1.00000000e+00]])

# %% [markdown]
# construct heatmap with 10 values

# %%
data = np.linspace (-5,5,10)
cov = cov_f1(data),cov_f2(data), cov_f3(data)
_,ax = plt.subplots(1,2, figsize=(12,8))
ax = np.ravel(ax)
ax[0].plot(data, np.zeros_like(data), 'ko')
ax[0].set_yticks([])
for idx, i in enumerate(data):
    ax[0].text(i, 0+0.005, idx)
ax[0].set_xticks(data)
ax[0].set_xticklabels(np.round(data, 2), rotation=70)

ax[1].grid(False)
im = ax[1].imshow(cov)
colors = ['w', 'k']
for i in range(len(cov)):
  for j in range(len(cov)):
      ax[1].text(j, i, round(cov[i, j], 2),
      color=colors[int(im.norm(cov[i, j]) > 0.5)],
      ha='center', va='center', fontdict={'size': 16})
ax[1].set_xticks(range(len(data)))
ax[1].set_yticks(range(len(data)))
ax[1].xaxis.tick_top()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:706: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x = np.array(x, subok=True, copy=copy)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1fab689cde7b> in <module>()
#      11
#      12 ax[1].grid(False)
# ---> 13 im = ax[1].imshow(cov)
#      14 colors = ['w', 'k']
#      15 for i in range(len(cov)):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
data = np.linspace (-5,5,10)
cov = cov_f1(data)
_,ax = plt.subplots(1,2, figsize=(30,30))
ax = np.ravel(ax)
ax[0].plot(data, np.zeros_like(data), 'ko')
ax[0].set_yticks([])
for idx, i in enumerate(data):
    ax[0].text(i, 0+0.005, idx)
ax[0].set_xticks(data)
#ax[0].set_xticklabels(data)
ax[0].set_xticklabels(np.round(data, 2), rotation=100)

ax[1].grid(False)


im = ax[1].imshow(cov)

colors = ['r', 'b']
for i in range(len(cov)):
  for j in range(len(cov)):
      ax[1].text(j, i, round(cov[i, j], 2),
      color=colors[int(im.norm(cov[i, j]) > 0.5)],
      ha='center', va='center', fontdict={'size': 16})
ax[1].set_xticks(range(len(data)))
ax[1].set_yticks(range(len(data)))
ax[1].xaxis.tick_top()

# %% [markdown]
# THE FIRS KERNEL represents a symm. heatmap with diag values
#
# * each element in cov matrix is inverse proportional to the distance between two points
# * which results in comparing each data points with itself
# * smooth functions modelled by this kernel
# * the closer the points the more they become similar.

# %%
data = np.linspace (-5,5,10)
cov = cov_f2(data)
_,ax = plt.subplots(1,2, figsize=(30,30))
ax = np.ravel(ax)
ax[0].plot(data, np.zeros_like(data), 'ko')
ax[0].set_yticks([])
for idx, i in enumerate(data):
    ax[0].text(i, 0+0.005, idx)
ax[0].set_xticks(data)
#ax[0].set_xticklabels(data)
ax[0].set_xticklabels(np.round(data, 2), rotation=100)

ax[1].grid(False)


im = ax[1].imshow(cov)

colors = ['r', 'b']
for i in range(len(cov)):
  for j in range(len(cov)):
      ax[1].text(j, i, round(cov[i, j], 2),
      color=colors[int(im.norm(cov[i, j]) > 0.5)],
      ha='center', va='center', fontdict={'size': 16})
ax[1].set_xticks(range(len(data)))
ax[1].set_yticks(range(len(data)))
ax[1].xaxis.tick_top()

# %%
data = np.linspace (-5,5,10)
cov = cov_f3(data)
_,ax = plt.subplots(1,2, figsize=(30,30))
ax = np.ravel(ax)
ax[0].plot(data, np.zeros_like(data), 'ko')
ax[0].set_yticks([])
for idx, i in enumerate(data):
    ax[0].text(i, 0+0.005, idx)
ax[0].set_xticks(data)
#ax[0].set_xticklabels(data)
ax[0].set_xticklabels(np.round(data, 2), rotation=100)

ax[1].grid(False)


im = ax[1].imshow(cov)

colors = ['r', 'b']
for i in range(len(cov)):
  for j in range(len(cov)):
      ax[1].text(j, i, round(cov[i, j], 2),
      color=colors[int(im.norm(cov[i, j]) > 0.5)],
      ha='center', va='center', fontdict={'size': 16})
ax[1].set_xticks(range(len(data)))
ax[1].set_yticks(range(len(data)))
ax[1].xaxis.tick_top()

# %%
cov_1_p = cov_f1(data)
mu_p_1 = np.zeros_like(data)
Y_prior_1 = np.random.multivariate_normal(mu_p_1, cov_1_p, 5)

# %%
cov_2_p = cov_f2(data)
mu_p_1 = np.zeros_like(data)
Y_prior_2 = np.random.multivariate_normal(mu_p_1, cov_2_p, 5)

# %%
cov_3_p = cov_f3(data)
mu_p_1 = np.zeros_like(data)
Y_prior_3 = np.random.multivariate_normal(mu_p_1, cov_3_p, 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: covariance is not positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
_, ax = plt.subplots(3,1, figsize=(20,20));
ax[0].plot(data, Y_prior_1.T, label = "5 priors using first covariance matrix");
ax[1].plot(data, Y_prior_2.T, label = "5 priors using second covariance matrix");
ax[2].plot(data, Y_prior_3.T, label = "5 priors using third covariance matrix");

# %% [markdown]
# q3.3

# %%
x = np.array([-4,2,4])
f = np.array([-0.5,0.5,0])

# %%
n =100
x_prior = np.linspace(-4, 4, n)
def Kernel(x):
    return np.exp(-np.array([(x-xi)**2 for xi in x]))

# %%
K_prior = Kernel(x_prior)
mu_prior = np.zeros_like(x_prior)
f_prior = np.random.multivariate_normal(mu_prior, K_prior,10)

# %%
x_joint = np.r_[x,x_prior]
K_joint = Kernel(x_joint)

# %%
n = x.size
K = K_joint[:n,:n]
Kx = K_joint[n:,:n]
Kxx = K_joint[n:,n:]

# %%
mu_posterior = Kx@np.linalg.inv(K)@f
K_posterior = Kxx - Kx@np.linalg.inv(K)@Kx.T
f_posterior = np.random.multivariate_normal(mu_posterior, K_posterior,10)

# %%
_,ax = plt.subplots(4,2, figsize=(12,8))
ax[0,0].plot(x_prior, f_prior.T)
ax[0,1].scatter(x,f, color='r')
ax[1,0].plot(x_prior, f_posterior.T)

ax[1,1].plot(x_prior, f_posterior.T, color='grey')
ax[1,1].scatter(x,f, zorder=3, color='r')

ax[2,0].plot(x_prior, mu_posterior, color='black')
ax[2,0].plot(x_prior, f_posterior.T, color='grey', alpha=0.4)
ax[2,0].scatter(x,f, zorder=3, color='r')

ax[2,1].fill_between(x_prior, mu_posterior+ np.sqrt(np.diag(K_posterior)),
                     mu_posterior - np.sqrt(np.diag(K_posterior)), color='grey')
ax[2,1].plot(x_prior, mu_posterior, color='black')
ax[2,1].plot(x_prior, f_posterior.T, color='grey', alpha=0.4)
ax[2,1].scatter(x,f, zorder=3, color='r')

ax[3,0].fill_between(x_prior, mu_posterior +  np.sqrt(np.diag(K_posterior)),
                     mu_posterior - np.sqrt(np.diag(K_posterior)), color='grey', alpha=0.5)

ax[3,0].fill_between(x_prior, mu_posterior + 2*np.sqrt(np.diag(K_posterior)),
                     mu_posterior - 2*np.sqrt(np.diag(K_posterior)), color='grey', alpha=0.5)

ax[3,0].plot(x_prior, mu_posterior, color='black')
ax[3,0].plot(x_prior, f_posterior.T, color='grey', alpha=0.4)
ax[3,0].scatter(x,f, zorder=3, color='r')

ax[3,1].fill_between(x_prior, mu_posterior +  np.sqrt(np.diag(K_posterior)),
                     mu_posterior - np.sqrt(np.diag(K_posterior)), color='grey', alpha=0.5)

ax[3,0].fill_between(x_prior, mu_posterior + 2*np.sqrt(np.diag(K_posterior)),
                     mu_posterior - 2*np.sqrt(np.diag(K_posterior)), color='grey', alpha=0.5)

ax[3,1].plot(x_prior, mu_posterior, color='black')
ax[3,1].plot(x_prior, f_posterior.T, color='grey', alpha=0.4)
ax[3,1].scatter(x,f, zorder=3, color='r')
plt.show()

# %%
Kx  = np.exp(-0.5*np.array([(x-xi)**2 for xi in x]))
Kx

# %%
def kernel(X,Y):
  kern = lambda x,y: np.exp(-1/2 * np.linalg.norm([x-y],2)**2)
  K = np.empty((len(X), len(Y)))
  for i, x in enumerate(X):
      for j, y in enumerate(Y):
        K[i,j] = kern(x,y)
  return K

fig,axes = plt.subplots(1,3)
cov_funcs = [kernel]
n =100
